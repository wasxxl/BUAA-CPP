# %%
import pandas as pd

df = pd.read_csv('whole_record.csv')
df = df[df['qid']==6301][df['score']>0.9]

df.head(100)
# Out:
# C:\Users\12574\anaconda3\envs\mydl\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (2,20,21,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\12574\anaconda3\envs\mydl\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#         Unnamed: 0  Unnamed: 0.1   user_id user_name  submission_id  \
# 100803      100803             0     -----       李恺辰        4911109
# 100804      100804             1  22373459       林炜程        4834243
# 100808      100808             5  22371111       金俊辉        4834053
# 100810      100810             7  22371118        黄睿        4834034
# 100811      100811             8  22373221       郑吕吕        4833648
# ...            ...           ...       ...       ...            ...
# ...

# %%
for idx,row in df.head(10).iterrows():
    print(row['code'])
    print('--------------------------------------------')
# Out:
# #include<stdio.h>_x000D_
# int a[200];_x000D_
# void sort1(int n){_x000D_
# 	int i,j,k;_x000D_
# 	for(i=0;i<n-1;i++){_x000D_
# 		for(j=0;j<n-1-i;j++){_x000D_
# 			if(a[j]>a[j+1]){_x000D_
# 				k=a[j+1];_x000D_
# 				a[j+1]=a[j];_x000D_
# 				a[j]=k;_x000D_
# 			}_x000D_
# 		}_x000D_
# 	}_x000D_
# }_x000D_
# int main(){_x000D_
# 	int n,i;_x000D_
# 	scanf("%d",&n);_x000D_
# 	for(i=0;i<n;i++) scanf("%d",&a[i]);_x000D_
# 	sort1(n);_x000D_
# 	for(i=0;i<n;i++) printf("%d ",a[i]);_x000D_
# 	printf("\n");_x000D_
# 	for(i=n-1;i>=0;i--) printf("%d ",a[i]);_x000D_
# }
# --------------------------------------------
# #include<stdio.h>_x000D_
# #include<math.h>_x000D_
# int a[100],m,i,j,r;_x000D_
# void burank(int r)_x000D_
# {_x000D_
#     j=0;_x000D_
#     while(j<r-1)_x000D_
#     {_x000D_
#         i=0;_x000D_
#         while(i<r-1-j)_x000D_
#         {_x000D_
#             if(a[i]>a[i+1])_x000D_
#             {_x000D_
#                 m=a[i];_x000D_
#                 a[i]=a[i+1];_x000D_
# ...
